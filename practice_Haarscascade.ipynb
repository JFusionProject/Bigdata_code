# %%
import cv2

# %%
face_cascade = cv2.CascadeClassifier('./opencv/haarcascade_frontalface_default.xml')
eye_casecade =  cv2.CascadeClassifier('./opencv/haarcascade_eye.xml')

# %%
img = cv2.imread('./data/ele3.png')

# %%
img
# Out:
# array([[[ 21,  35,  30],
#         [ 40,  55,  50],
#         [ 37,  51,  46],
#         ...,
#         [ 15,  25,  22],
#         [ 16,  27,  24],
#         [  1,  11,   9]],
#
#        [[ 51,  75,  67],
#         [ 73,  97,  91],
#         [ 71,  96,  89],
#         ...,
#         [ 41,  52,  49],
#         [ 43,  53,  51],
#         [ 26,  37,  34]],
#
#        [[ 45,  79,  70],
#         [ 73, 107,  97],
#         [ 70, 104,  95],
#         ...,
#         [ 45,  55,  53],
#         [ 47,  58,  55],
#         [ 29,  41,  38]],
#
#        ...,
#
#        [[  0,   0,   0],
#         [  0,  11,   0],
#         [  0,  13,   0],
#         ...,
#         [ 82, 103,  85],
#         [ 82, 103,  85],
#         [ 44,  65,  46]],
#
#        [[  0,   0,   0],
#         [  2,  14,   0],
#         [  7,  20,   5],
#         ...,
#         [ 85, 105,  87],
#         [ 85, 104,  86],
#         [ 48,  67,  50]],
#
#        [[  0,  10,   0],
#         [ 18,  31,  18],
#         [ 23,  36,  22],
# ...

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
img.shape
# Out:
# (423, 719, 3)

# %%
plt.imshow(img)

# %%
faces
# Out:
# array([[178, 213,  52,  52],
#        [371, 103,  87,  87],
#        [411, 204,  64,  64],
#        [497, 230,  65,  65],
#        [309, 245,  98,  98],
#        [ 20, 229,  83,  83],
#        [206, 276,  52,  52],
#        [507, 292, 127, 127]], dtype=int32)

# %%
ROI_face.shape
# Out:
# (64, 64)

# %%
faces = face_cascade.detectMultiScale(
        img,
        scaleFactor=1.1,     # 이미지에서 얼굴 크기가 서로 다른 것을 보상해주는 값
        minNeighbors=3   # 얼굴 사이의 최소 간격(픽셀)입니다
    )

imgNum=0
final = [ ]
for (x,y,w,h) in faces:
    # cv2.rectangle(img, (x,y), (x+w, y+h), (255,0,0),2)
    ROI_face = img[y:y + h, x:x + w]
    ROI_face = cv2.resize(ROI_face, (64, 64))
    # 이미지를 저장
    # cv2.imwrite("thumbnail" + str(imgNum) + ".png", ROI_face)
    # imgNum += 1
    face_list = ROI_face.tolist()
    final.append(face_list)
    
cv2.imshow('Image view', img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-289-5901dc16a779> in <module>
#      18
#      19 cv2.imshow('Image view', img)
# ---> 20 cv2.waitKey(0)
#      21 cv2.destroyAllWindows()
#
# KeyboardInterrupt:

# %%
final
# Out:
# [[[[124, 135, 113],
#    [125, 136, 114],
#    [124, 136, 114],
#    [123, 135, 113],
#    [120, 132, 111],
#    [116, 126, 113],
#    [101, 110, 100],
#    [71, 76, 69],
#    [42, 43, 39],
#    [24, 22, 21],
#    [17, 12, 14],
#    [18, 11, 14],
#    [18, 11, 14],
#    [18, 11, 14],
#    [18, 11, 14],
#    [17, 11, 14],
#    [18, 11, 12],
#    [19, 11, 12],
#    [19, 11, 13],
#    [20, 10, 14],
#    [19, 10, 15],
#    [18, 9, 15],
#    [17, 10, 15],
#    [17, 10, 15],
#    [18, 12, 16],
#    [18, 13, 17],
#    [18, 15, 17],
#    [21, 17, 18],
#    [23, 17, 18],
#    [22, 16, 17],
#    [22, 15, 17],
#    [21, 15, 17],
#    [23, 17, 18],
#    [23, 18, 19],
#    [23, 19, 20],
#    [24, 20, 21],
#    [24, 20, 22],
#    [25, 21, 23],
#    [26, 22, 23],
#    [26, 21, 22],
#    [24, 18, 19],
#    [20, 14, 15],
#    [19, 12, 13],
#    [19, 11, 13],
#    [20, 12, 14],
#    [21, 12, 14],
#    [22, 12, 14],
#    [22, 12, 14],
#    [22, 12, 14],
#    [22, 12, 14],
#    [21, 12, 13],
# ...

# %%
plt.imshow(np.array(final[4]))
